# %%
from PyQt5 import QtCore, QtGui, QtWidgets

# %%
class Ui_EntryformDialog(object):
    def setupUi(self, EntryformDialog):
        EntryformDialog.setObjectName("EntryformDialog")
        EntryformDialog.resize(528, 790)
        EntryformDialog.setCursor(QtGui.QCursor(QtCore.Qt.UpArrowCursor))
        self.ADStitle = QtWidgets.QLabel(EntryformDialog)
        self.ADStitle.setGeometry(QtCore.QRect(60, 20, 401, 31))
        font = QtGui.QFont()
        font.setFamily("Arial")
        font.setPointSize(18)
        font.setBold(False)
        font.setWeight(50)
        self.ADStitle.setFont(font)
        self.ADStitle.setObjectName("ADStitle")
        self.statuslabel = QtWidgets.QLabel(EntryformDialog)
        self.statuslabel.setGeometry(QtCore.QRect(40, 70, 41, 21))
        self.statuslabel.setObjectName("statuslabel")
        self.msidlabel = QtWidgets.QLabel(EntryformDialog)
        self.msidlabel.setGeometry(QtCore.QRect(40, 100, 51, 21))
        self.msidlabel.setObjectName("msidlabel")
        self.teamnamelabel = QtWidgets.QLabel(EntryformDialog)
        self.teamnamelabel.setGeometry(QtCore.QRect(40, 160, 61, 21))
        self.teamnamelabel.setObjectName("teamnamelabel")
        self.fullnamelabel = QtWidgets.QLabel(EntryformDialog)
        self.fullnamelabel.setGeometry(QtCore.QRect(40, 130, 51, 20))
        self.fullnamelabel.setObjectName("fullnamelabel")
        self.issuedescriptionlabel = QtWidgets.QLabel(EntryformDialog)
        self.issuedescriptionlabel.setGeometry(QtCore.QRect(40, 250, 91, 21))
        self.issuedescriptionlabel.setObjectName("issuedescriptionlabel")
        self.keytermlabel = QtWidgets.QLabel(EntryformDialog)
        self.keytermlabel.setGeometry(QtCore.QRect(40, 220, 51, 21))
        self.keytermlabel.setObjectName("keytermlabel")
        self.categorylabel = QtWidgets.QLabel(EntryformDialog)
        self.categorylabel.setGeometry(QtCore.QRect(40, 190, 51, 21))
        self.categorylabel.setObjectName("categorylabel")
        self.datelabel = QtWidgets.QLabel(EntryformDialog)
        self.datelabel.setGeometry(QtCore.QRect(290, 220, 41, 21))
        self.datelabel.setObjectName("datelabel")
        self.escalatedtolabel = QtWidgets.QLabel(EntryformDialog)
        self.escalatedtolabel.setGeometry(QtCore.QRect(40, 440, 61, 21))
        self.escalatedtolabel.setObjectName("escalatedtolabel")
        self.adsmemberlabel = QtWidgets.QLabel(EntryformDialog)
        self.adsmemberlabel.setGeometry(QtCore.QRect(40, 500, 71, 21))
        self.adsmemberlabel.setObjectName("adsmemberlabel")
        self.resolutionlabel = QtWidgets.QLabel(EntryformDialog)
        self.resolutionlabel.setGeometry(QtCore.QRect(40, 340, 61, 21))
        self.resolutionlabel.setObjectName("resolutionlabel")
        self.typelabel = QtWidgets.QLabel(EntryformDialog)
        self.typelabel.setGeometry(QtCore.QRect(290, 160, 51, 16))
        self.typelabel.setObjectName("typelabel")
        self.ticketnolabel = QtWidgets.QLabel(EntryformDialog)
        self.ticketnolabel.setGeometry(QtCore.QRect(290, 440, 71, 21))
        self.ticketnolabel.setObjectName("ticketnolabel")
        self.jiralabel = QtWidgets.QLabel(EntryformDialog)
        self.jiralabel.setGeometry(QtCore.QRect(40, 470, 31, 21))
        self.jiralabel.setObjectName("jiralabel")
        self.regionlabel = QtWidgets.QLabel(EntryformDialog)
        self.regionlabel.setGeometry(QtCore.QRect(290, 130, 51, 16))
        self.regionlabel.setObjectName("regionlabel")
        self.rolelabel = QtWidgets.QLabel(EntryformDialog)
        self.rolelabel.setGeometry(QtCore.QRect(290, 100, 47, 20))
        self.rolelabel.setObjectName("rolelabel")
        self.categorizationlabel = QtWidgets.QLabel(EntryformDialog)
        self.categorizationlabel.setGeometry(QtCore.QRect(290, 70, 81, 21))
        self.categorizationlabel.setObjectName("categorizationlabel")
        self.subcategorylabel = QtWidgets.QLabel(EntryformDialog)
        self.subcategorylabel.setGeometry(QtCore.QRect(290, 190, 71, 21))
        self.subcategorylabel.setObjectName("subcategorylabel")
        self.sourcelabel = QtWidgets.QLabel(EntryformDialog)
        self.sourcelabel.setGeometry(QtCore.QRect(290, 470, 31, 20))
        self.sourcelabel.setObjectName("sourcelabel")
        self.shiftlabel = QtWidgets.QLabel(EntryformDialog)
        self.shiftlabel.setGeometry(QtCore.QRect(290, 500, 41, 21))
        self.shiftlabel.setObjectName("shiftlabel")
        self.timetakenlabel = QtWidgets.QLabel(EntryformDialog)
        self.timetakenlabel.setGeometry(QtCore.QRect(40, 530, 61, 21))
        self.timetakenlabel.setObjectName("timetakenlabel")
        self.msidinput = QtWidgets.QLineEdit(EntryformDialog)
        self.msidinput.setGeometry(QtCore.QRect(120, 100, 113, 20))
        self.msidinput.setObjectName("msidinput")
        self.fullnameinput = QtWidgets.QLineEdit(EntryformDialog)
        self.fullnameinput.setGeometry(QtCore.QRect(120, 130, 113, 20))
        self.fullnameinput.setObjectName("fullnameinput")
        self.teamnameinput = QtWidgets.QLineEdit(EntryformDialog)
        self.teamnameinput.setGeometry(QtCore.QRect(120, 160, 113, 20))
        self.teamnameinput.setObjectName("teamnameinput")
        self.regioninput = QtWidgets.QLineEdit(EntryformDialog)
        self.regioninput.setGeometry(QtCore.QRect(370, 130, 113, 20))
        self.regioninput.setObjectName("regioninput")
        self.roleinput = QtWidgets.QLineEdit(EntryformDialog)
        self.roleinput.setGeometry(QtCore.QRect(370, 100, 113, 20))
        self.roleinput.setObjectName("roleinput")
        self.issueinput = QtWidgets.QPlainTextEdit(EntryformDialog)
        self.issueinput.setGeometry(QtCore.QRect(40, 280, 441, 51))
        self.issueinput.setObjectName("issueinput")
        self.resolutioninput = QtWidgets.QPlainTextEdit(EntryformDialog)
        self.resolutioninput.setGeometry(QtCore.QRect(40, 370, 441, 51))
        self.resolutioninput.setObjectName("resolutioninput")
        self.statusselect = QtWidgets.QComboBox(EntryformDialog)
        self.statusselect.setGeometry(QtCore.QRect(120, 70, 111, 22))
        self.statusselect.setEditable(False)
        self.statusselect.setObjectName("statusselect")
        self.categorizationselect = QtWidgets.QComboBox(EntryformDialog)
        self.categorizationselect.setGeometry(QtCore.QRect(370, 70, 111, 22))
        self.categorizationselect.setObjectName("categorizationselect")
        self.typeselect = QtWidgets.QComboBox(EntryformDialog)
        self.typeselect.setGeometry(QtCore.QRect(370, 160, 111, 22))
        self.typeselect.setEditable(True)
        self.typeselect.setObjectName("typeselect")
        self.categoryselect = QtWidgets.QComboBox(EntryformDialog)
        self.categoryselect.setGeometry(QtCore.QRect(120, 190, 111, 22))
        self.categoryselect.setEditable(False)
        self.categoryselect.setObjectName("categoryselect")
        self.subcategoryselect = QtWidgets.QComboBox(EntryformDialog)
        self.subcategoryselect.setGeometry(QtCore.QRect(370, 190, 111, 22))
        self.subcategoryselect.setEditable(True)
        self.subcategoryselect.setObjectName("subcategoryselect")
        self.sourceselect = QtWidgets.QComboBox(EntryformDialog)
        self.sourceselect.setGeometry(QtCore.QRect(370, 470, 111, 22))
        self.sourceselect.setObjectName("sourceselect")
        self.shiftselect = QtWidgets.QComboBox(EntryformDialog)
        self.shiftselect.setGeometry(QtCore.QRect(370, 500, 111, 22))
        self.shiftselect.setObjectName("shiftselect")
        self.adsmemberselect = QtWidgets.QComboBox(EntryformDialog)
        self.adsmemberselect.setGeometry(QtCore.QRect(120, 500, 111, 22))
        self.adsmemberselect.setObjectName("adsmemberselect")
        self.jirainput = QtWidgets.QLineEdit(EntryformDialog)
        self.jirainput.setGeometry(QtCore.QRect(120, 470, 113, 20))
        self.jirainput.setObjectName("jirainput")
        self.escalatedtoselect = QtWidgets.QComboBox(EntryformDialog)
        self.escalatedtoselect.setGeometry(QtCore.QRect(120, 440, 111, 22))
        self.escalatedtoselect.setEditable(True)
        self.escalatedtoselect.setObjectName("escalatedtoselect")
        self.ticketnumberinput = QtWidgets.QLineEdit(EntryformDialog)
        self.ticketnumberinput.setGeometry(QtCore.QRect(370, 440, 111, 20))
        self.ticketnumberinput.setObjectName("ticketnumberinput")
        self.searchbutton = QtWidgets.QToolButton(EntryformDialog)
        self.searchbutton.setGeometry(QtCore.QRect(461, 440, 21, 21))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.searchbutton.setFont(font)
        self.searchbutton.setObjectName("searchbutton")
        self.timeEdit = QtWidgets.QTimeEdit(EntryformDialog)
        self.timeEdit.setGeometry(QtCore.QRect(120, 530, 111, 22))
        font = QtGui.QFont()
        font.setStyleStrategy(QtGui.QFont.PreferAntialias)
        self.timeEdit.setFont(font)
        self.timeEdit.setButtonSymbols(QtWidgets.QAbstractSpinBox.NoButtons)
        self.timeEdit.setDate(QtCore.QDate(2000, 3, 1))
        self.timeEdit.setObjectName("timeEdit")
        self.keytermselect = QtWidgets.QComboBox(EntryformDialog)
        self.keytermselect.setGeometry(QtCore.QRect(120, 220, 111, 22))
        self.keytermselect.setObjectName("keytermselect")
        self.savenshowdatabutton = QtWidgets.QPushButton(EntryformDialog)
        self.savenshowdatabutton.setGeometry(QtCore.QRect(170, 570, 171, 31))
        font = QtGui.QFont()
        font.setPointSize(9)
        font.setBold(True)
        font.setWeight(75)
        self.savenshowdatabutton.setFont(font)
        self.savenshowdatabutton.setObjectName("savenshowdatabutton")
        self.showdatatable = QtWidgets.QTableView(EntryformDialog)
        self.showdatatable.setGeometry(QtCore.QRect(40, 620, 441, 71))
        self.showdatatable.setObjectName("showdatatable")
        self.commitnsavetoexcelbutton = QtWidgets.QPushButton(EntryformDialog)
        self.commitnsavetoexcelbutton.setGeometry(QtCore.QRect(260, 710, 171, 31))
        font = QtGui.QFont()
        font.setPointSize(9)
        font.setBold(True)
        font.setWeight(75)
        self.commitnsavetoexcelbutton.setFont(font)
        self.commitnsavetoexcelbutton.setObjectName("commitnsavetoexcelbutton")
        self.viewneditdatabutton = QtWidgets.QPushButton(EntryformDialog)
        self.viewneditdatabutton.setGeometry(QtCore.QRect(80, 710, 171, 31))
        font = QtGui.QFont()
        font.setPointSize(9)
        font.setBold(True)
        font.setWeight(75)
        self.viewneditdatabutton.setFont(font)
        self.viewneditdatabutton.setObjectName("viewneditdatabutton")
        self.dateTimeEdit = QtWidgets.QDateTimeEdit(EntryformDialog)
        self.dateTimeEdit.setGeometry(QtCore.QRect(370, 220, 111, 22))
        font = QtGui.QFont()
        font.setPointSize(8)
        self.dateTimeEdit.setFont(font)
        self.dateTimeEdit.setProperty("showGroupSeparator", False)
        self.dateTimeEdit.setMaximumDateTime(QtCore.QDateTime(QtCore.QDate(9999, 11, 30), QtCore.QTime(23, 59, 59)))
        self.dateTimeEdit.setCurrentSection(QtWidgets.QDateTimeEdit.DaySection)
        self.dateTimeEdit.setCalendarPopup(True)
        self.dateTimeEdit.setTimeSpec(QtCore.Qt.LocalTime)
        self.dateTimeEdit.setObjectName("dateTimeEdit")

        self.retranslateUi(EntryformDialog)
        QtCore.QMetaObject.connectSlotsByName(EntryformDialog)

    def retranslateUi(self, EntryformDialog):
        _translate = QtCore.QCoreApplication.translate
        EntryformDialog.setWindowTitle(_translate("EntryformDialog", "Dialog"))
        self.ADStitle.setText(_translate("EntryformDialog", "Authoring Deployment Support CRM"))
        self.statuslabel.setText(_translate("EntryformDialog", "Status"))
        self.msidlabel.setText(_translate("EntryformDialog", "MSID"))
        self.teamnamelabel.setText(_translate("EntryformDialog", "Team Name"))
        self.fullnamelabel.setText(_translate("EntryformDialog", "Full Name"))
        self.issuedescriptionlabel.setText(_translate("EntryformDialog", "Issue Description"))
        self.keytermlabel.setText(_translate("EntryformDialog", "Keyterm"))
        self.categorylabel.setText(_translate("EntryformDialog", "Category"))
        self.datelabel.setText(_translate("EntryformDialog", "Date"))
        self.escalatedtolabel.setText(_translate("EntryformDialog", "Escalated to"))
        self.adsmemberlabel.setText(_translate("EntryformDialog", "ADS Member"))
        self.resolutionlabel.setText(_translate("EntryformDialog", "Resolution"))
        self.typelabel.setText(_translate("EntryformDialog", "Type"))
        self.ticketnolabel.setText(_translate("EntryformDialog", "Ticket Number"))
        self.jiralabel.setText(_translate("EntryformDialog", "Jira"))
        self.regionlabel.setText(_translate("EntryformDialog", "Region"))
        self.rolelabel.setText(_translate("EntryformDialog", "Role"))
        self.categorizationlabel.setText(_translate("EntryformDialog", "Categorization"))
        self.subcategorylabel.setText(_translate("EntryformDialog", "Sub-Category"))
        self.sourcelabel.setText(_translate("EntryformDialog", "Source"))
        self.shiftlabel.setText(_translate("EntryformDialog", "Shift"))
        self.timetakenlabel.setText(_translate("EntryformDialog", "Time Taken"))
        self.searchbutton.setWhatsThis(_translate("EntryformDialog", "<html><head/><body><p>Fetch data</p></body></html>"))
        self.searchbutton.setText(_translate("EntryformDialog", "🔍"))
        self.timeEdit.setDisplayFormat(_translate("EntryformDialog", "mmm"))
        self.savenshowdatabutton.setText(_translate("EntryformDialog", "Save and Show Data"))
        self.commitnsavetoexcelbutton.setText(_translate("EntryformDialog", "Commit and Save to Excel"))
        self.viewneditdatabutton.setText(_translate("EntryformDialog", "View and Edit Data"))
        self.dateTimeEdit.setDisplayFormat(_translate("EntryformDialog", "dd-MMM-yy hh:mm"))

# %%
if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    EntryformDialog = QtWidgets.QDialog()
    ui = Ui_EntryformDialog()
    ui.setupUi(EntryformDialog)
    EntryformDialog.show()
    sys.exit(app.exec_())
